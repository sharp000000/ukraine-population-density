# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
population = pd.read_csv('population.csv',delimiter=';').drop(['Unnamed: 2','Unnamed: 3'],axis=1)

# %%
population.sort_values('region').head()
# Out:
#    population           region
# 0   1181860.0         Cherkasy
# 1    980290.0        Chernihiv
# 2    897922.0       Chernivtsi
# 4   3150407.0  Dnipropetrovs'k
# 5   4106841.0         Donets'k

# %%
fp = "UKR_adm/UKR_adm1.shp"
map_df = gpd.read_file(fp)

# %%
map_df.head()
# Out:
#    ID_0  ISO   NAME_0  ID_1           NAME_1               TYPE_1  \
# 0   240  UKR  Ukraine     1         Cherkasy              Oblast'
# 1   240  UKR  Ukraine     2        Chernihiv              Oblast'
# 2   240  UKR  Ukraine     3       Chernivtsi              Oblast'
# 3   240  UKR  Ukraine     4           Crimea  Autonomous Republic
# 4   240  UKR  Ukraine     5  Dnipropetrovs'k              Oblast'
#
#              ENGTYPE_1 NL_NAME_1  \
# 0               Region      None
# 1               Region      None
# 2               Region      None
# 3  Autonomous Republic      None
# 4               Region      None
#
#                                            VARNAME_1  \
# 0  Cherkas'ka Oblast'|Cherkasskaya Oblast'|Cherkassy
# 1                              Chernigov|Tschernigow
# 2  Chernivets'ka Oblast'|Chernovitskaya Oblast'|C...
# 3  Crimée|Criméia|Krim|Krymskaya Respublika|Respu...
# 4    Dnipropetrovsk|Dniepropietrovsk|Dnjepropetrowsk
#
#                                             geometry
# 0  POLYGON ((32.15047 50.19769, 32.15050 50.19181...
# 1  POLYGON ((33.19667 52.37500, 33.20612 52.36700...
# 2  POLYGON ((25.62595 48.67673, 25.64460 48.67159...
# 3  MULTIPOLYGON (((33.79458 44.39153, 33.79291 44...
# 4  POLYGON ((34.92995 49.15574, 34.92076 49.14992...

# %%
population_full = map_df.merge(population,left_on='NAME_1',right_on='region')

# %%
# plt.rcParams['figure.figsize'] = [15, 20] #height, width
# map_df.plot()

# %%
import mapclassify
import geoplot

geoplot.choropleth(
    population_full, hue='population',
    cmap='Blues', figsize=(20,16)
)
# Out:
# <AxesSubplot:>

# %%
population_full.sort_values('population')
# Out:
#     ID_0  ISO   NAME_0  ID_1            NAME_1            TYPE_1  \
# 2    240  UKR  Ukraine     3        Chernivtsi           Oblast'
# 11   240  UKR  Ukraine    13        Kirovohrad           Oblast'
# 1    240  UKR  Ukraine     2         Chernihiv           Oblast'
# 7    240  UKR  Ukraine     9           Kherson           Oblast'
# 22   240  UKR  Ukraine    25             Volyn           Oblast'
# 19   240  UKR  Ukraine    22         Ternopil'           Oblast'
# 18   240  UKR  Ukraine    21              Sumy           Oblast'
# 14   240  UKR  Ukraine    16         Mykolayiv           Oblast'
# 17   240  UKR  Ukraine    19             Rivne           Oblast'
# 0    240  UKR  Ukraine     1          Cherkasy           Oblast'
# 24   240  UKR  Ukraine    27          Zhytomyr           Oblast'
# 8    240  UKR  Ukraine    10    Khmel'nyts'kyy           Oblast'
# 20   240  UKR  Ukraine    23    Transcarpathia           Oblast'
# 5    240  UKR  Ukraine     7  Ivano-Frankivs'k           Oblast'
# 16   240  UKR  Ukraine    18           Poltava           Oblast'
# 21   240  UKR  Ukraine    24         Vinnytsya           Oblast'
# 23   240  UKR  Ukraine    26      Zaporizhzhya           Oblast'
# 10   240  UKR  Ukraine    12              Kiev           Oblast'
# 13   240  UKR  Ukraine    15          Luhans'k           Oblast'
# 15   240  UKR  Ukraine    17            Odessa           Oblast'
# 12   240  UKR  Ukraine    14             L'viv           Oblast'
# 6    240  UKR  Ukraine     8           Kharkiv           Oblast'
# 9    240  UKR  Ukraine    11         Kiev City  Independent City
# 3    240  UKR  Ukraine     5   Dnipropetrovs'k           Oblast'
# 4    240  UKR  Ukraine     6          Donets'k           Oblast'
#
#            ENGTYPE_1 NL_NAME_1  \
# 2             Region      None
# 11            Region      None
# 1             Region      None
# 7             Region      None
# 22            Region      None
# 19            Region      None
# 18            Region      None
# 14            Region      None
# 17            Region      None
# 0             Region      None
# 24            Region      None
# 8             Region      None
# 20            Region      None
# 5             Region      None
# 16            Region      None
# 21            Region      None
# 23            Region      None
# 10            Region      None
# 13            Region      None
# 15            Region      None
# 12            Region      None
# 6             Region      None
# 9   Independent City      None
# 3             Region      None
# 4             Region      None
#
#                                             VARNAME_1  \
# 2   Chernivets'ka Oblast'|Chernovitskaya Oblast'|C...
# 11                 Kirovograd|Kirovogradskaya Oblast'
# 1                               Chernigov|Tschernigow
# 7                         Cherson|Khersons'ka Oblast'
# 22  Volhynia|Volyns'ka Oblast'|Volynskaya Oblast'|...
# 19                                 Ternopol|Ternopol'
# 18                                               None
# 14                       Mykolaiv|Nikolajew|Nikolayev
# 17        Rovno|Rivnens'ka Oblast'|Rovenskaya Oblast'
# 0   Cherkas'ka Oblast'|Cherkasskaya Oblast'|Cherkassy
# 24    Zhitomir|Jitomir|Shitomir|Zhitomirskaya Oblast'
# 8   Khmelnitsky|Khmelnytskyi|Chmelnizkij|Hmelnicki...
# 20  Transcarpathian|Zakarpattia|Ruthenia|Zakarpats...
# 5   Ivano-Frankovsk|Ivano-Frankovskaya Oblast'|Sta...
# 16                                               None
# 21  Vinnytsia|Vinnitskaya Oblast'|Vinnyts'ka Oblas...
# 23  Saporoshje|Zaporizhia|Zaporiz'ka Oblast'|Zapor...
# 10  Kiev Oblast|Kiew|Kijew|Kiiv|Kijev|Kiyev|Kyiv|K...
# 13   Luhansk|Lugansk|Luhans'ka Oblast'|Voroshilovgrad
# 15            Odesa|Odes'ka Oblast'|Odesskaya Oblast'
# 12         Lemberg|Llvov|L'vov|Lwow|L'vivs'ka Oblast'
# 6                      Charkow|Jarkov|Karkov|Khar'kov
# 9                                                Kyiv
# 3     Dnipropetrovsk|Dniepropietrovsk|Dnjepropetrowsk
# 4           Donetsk|Donetskaya Oblast'|Donezk|Stalino
#
#                                              geometry  population  \
# 2   POLYGON ((25.62595 48.67673, 25.64460 48.67159...    897922.0
# 11  POLYGON ((32.95085 49.20770, 32.96899 49.20749...    923254.0
# 1   POLYGON ((33.19667 52.37500, 33.20612 52.36700...    980290.0
# 7   MULTIPOLYGON (((34.05688 46.01227, 34.05639 46...   1019829.0
# 22  POLYGON ((25.30289 51.97861, 25.32052 51.97417...   1028781.0
# 19  POLYGON ((26.21350 50.25444, 26.21611 50.23071...   1032714.0
# 18  POLYGON ((33.79665 52.36000, 33.81583 52.34790...   1056779.0
# 14  MULTIPOLYGON (((31.41125 46.60264, 31.41125 46...   1111301.0
# 17  POLYGON ((25.82499 51.96153, 25.84438 51.95672...   1150037.0
# 0   POLYGON ((32.15047 50.19769, 32.15050 50.19181...   1181860.0
# 24  POLYGON ((28.25902 51.63647, 28.25941 51.63033...   1198749.0
# 8   POLYGON ((27.13142 50.56980, 27.14136 50.56425...   1246862.0
# 20  POLYGON ((22.60218 49.09510, 22.60193 49.09060...   1251479.0
# 5   POLYGON ((24.48923 49.53322, 24.49895 49.52786...   1363269.0
# 16  POLYGON ((34.03342 50.50913, 34.05145 50.49718...   1375491.0
# 21  POLYGON ((28.97885 49.83524, 28.97919 49.82933...   1533014.0
# 23  MULTIPOLYGON (((35.05986 46.15125, 35.05986 46...   1671748.0
# 10  POLYGON ((29.73023 51.52906, 29.73049 51.52345...   1788660.0
# 13  POLYGON ((38.34765 50.08024, 38.34533 50.06713...   2124316.0
# 15  MULTIPOLYGON (((30.20708 45.25764, 30.20708 45...   2371236.0
# 12  POLYGON ((24.21482 50.62987, 24.22468 50.62470...   2501502.0
# 6   POLYGON ((36.07391 50.46371, 36.08271 50.45771...   2640023.0
# 9   POLYGON ((30.46630 50.58701, 30.46658 50.58113...   2964448.0
# 3   POLYGON ((34.92995 49.15574, 34.92076 49.14992...   3150407.0
# 4   MULTIPOLYGON (((37.67542 47.08208, 37.67542 47...   4106841.0
#
#               region
# 2         Chernivtsi
# 11        Kirovohrad
# 1          Chernihiv
# 7            Kherson
# 22             Volyn
# 19         Ternopil'
# 18              Sumy
# 14         Mykolayiv
# 17             Rivne
# 0           Cherkasy
# 24          Zhytomyr
# 8     Khmel'nyts'kyy
# 20    Transcarpathia
# 5   Ivano-Frankivs'k
# 16           Poltava
# 21         Vinnytsya
# 23      Zaporizhzhya
# 10              Kiev
# 13          Luhans'k
# 15            Odessa
# 12             L'viv
# 6            Kharkiv
# 9          Kiev City
# 3    Dnipropetrovs'k
# 4           Donets'k
